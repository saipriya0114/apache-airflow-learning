# %% [markdown]
# <a href="https://colab.research.google.com/github/saipriya0114/apache-airflow-learning/blob/main/Day2_PythonOperators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from airflow import DAG
from airflow.providers.standard.operators.python import PythonOperator
from datetime import datetime

def extract():
    print("Extracting")

def transform():
    print("Transforming")

def load():
    print("Loading")

with DAG(
    dag_id='etl_pipeline',
    start_date=datetime(2026, 5, 13),
    schedule='@hourly',
    catchup=False
) as dag:

    task1 = PythonOperator(
        task_id='extract',
        python_callable=extract
    )

    task2 = PythonOperator(
        task_id='transform',
        python_callable=transform
    )

    task3 = PythonOperator(
        task_id='load',
        python_callable=load
    )

# %%
   task1 >> task2 >> task3
# Out:
# <Task(PythonOperator): load>
