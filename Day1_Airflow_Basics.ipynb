# %% [markdown]
# <a href="https://colab.research.google.com/github/saipriya0114/apache-airflow-learning/blob/main/Day1_Airflow_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from airflow import DAG

# %%
from airflow.providers.standard.operators.python import PythonOperator
from datetime import datetime

# %%
def say_hello():
  print("hello airflow")

# %%
def welcome_message():
  print("Welcome to data engineering")

# %%
with DAG(
    dag_id='first_dag',
    start_date=datetime(2026,5,13),
    schedule='@daily',
    catchup=False
) as dag:
    task1=PythonOperator(
        task_id='say_hello',
        python_callable=say_hello
    )
    task2=PythonOperator(
        task_id='welcome_message',
        python_callable=welcome_message
    )

# %%
task1 >> task2
# Out:
# <Task(PythonOperator): welcome_message>
